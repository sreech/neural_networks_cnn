# %%
import numpy as np
import pandas as pd
from subprocess import check_output
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.image as mpimg
import numpy as np
from numpy import random

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
#from keras.utils import np_utils
from keras.utils import to_categorical

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau, Callback
from keras import regularizers
from keras.optimizers import Adam

# %% [markdown]
# This is a dataset of handwritten grayscale images where each image is 28x28 pixels in .CSV format. Evaluating digits is much simpler than other image recognition problems so this is a perfect dataset for evaluating different models.

# %% [markdown]
# ###### Place the train.csv file in your google drive under the xpro path

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv("/content/drive/MyDrive/XPro/train.csv")
# test_df = pd.read_csv("/content/drive/MyDrive/XPro/test.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.sample(1)
# Out:
#        label  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 39851      6       0       0       0       0       0       0       0       0
#
#        pixel8  ...  pixel774  pixel775  pixel776  pixel777  pixel778  \
# 39851       0  ...         0         0         0         0         0
#
#        pixel779  pixel780  pixel781  pixel782  pixel783
# 39851         0         0         0         0         0
#
# [1 rows x 785 columns]

# %% [markdown]
# Write a method to visualize the images:

# %%
def display_images(X, y=[], rows=5, columns=5, cmap="gray"):
    """ Display images and labels
    """
    fig, ax = plt.subplots(rows,columns, figsize=(6,6))
    for row in range(rows):
        for column in range(columns):
            ax[row][column].imshow(X[(row*columns)+column].reshape(28,28), cmap=cmap)
            ax[row][column].set_axis_off()
            if len(y):ax[row][column].set_title("{}:{}".format("label",np.argmax(y[(row*columns)+column])))
    fig.tight_layout()

# %matplotlib inline

# %% [markdown]
# Training (60%): data used to train convnet;
# Cross validation (20%): data used to validate performance;
# Test (20%): data used to test the classification accuracy
#
# There is a separate test set available, but those images are not labeled so we cannot use them for evaluation.

# %%
#print(df.iloc[:,1:].values)
print(df.iloc[:,0].values)
# Out:
# [1 0 1 ... 7 6 9]

# %%
X_train, X_val, y_train, y_val = train_test_split(df.iloc[:,1:].values, df.iloc[:,0].values, test_size = 0.4)
X_cv, X_test, y_cv, y_test = train_test_split(X_val, y_val, test_size = 0.5)
print("X_train:{}\ny_train:{}\n\nX_cv:{}\ny_cv:{}\n\nX_test:{}\ny_test:{}".format(X_train.shape, y_train.shape, X_cv.shape, y_cv.shape, X_test.shape, y_test.shape))
# Out:
# X_train:(25200, 784)
# y_train:(25200,)
#
# X_cv:(8400, 784)
# y_cv:(8400,)
#
# X_test:(8400, 784)
# y_test:(8400,)

# %% [markdown]
# The images are in .CSV format meaning they are represented by 784 values. You need to reformat the data to be 28x28. You also need to normalize the gray scale from 0-255 to 0-1.

# %%
width = 28
height = 28
channels = 1
X_train = X_train.reshape(X_train.shape[0], width, height, channels)
X_cv = X_cv.reshape(X_cv.shape[0], width, height, channels)
X_test = X_test.reshape(X_test.shape[0], width, height, channels)

# convert output classes to one hot representation
y_train = to_categorical(y_train, num_classes=10)
y_cv = to_categorical(y_cv, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

X_train = X_train.astype('float32')
X_cv = X_cv.astype('float32')
X_test = X_test.astype('float32')

# Scale features (pixel values) from 0-255, to 0-1
X_train /= 255
X_cv /= 255
X_test /= 255
print("Reshaped:")
print("X_train:{}\ny_train:{}\n\nX_cv:{}\ny_cv:{}\n\nX_test:{}\ny_test:{}".format(X_train.shape, y_train.shape, X_cv.shape, y_cv.shape, X_test.shape, y_test.shape))
# Out:
# Reshaped:
# X_train:(25200, 28, 28, 1)
# y_train:(25200, 10)
#
# X_cv:(8400, 28, 28, 1)
# y_cv:(8400, 10)
#
# X_test:(8400, 28, 28, 1)
# y_test:(8400, 10)

# %%
print(X_train)

# %%
display_images(X_train, y_train)

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# You will be making three total models so you should define methods to standardize the models and maintain consistency.
#
# Try changing teh epochs and see how it affects your model

# %%
batch_size=84
epochs=30 # Change to 30
verbose=2

class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))


def create_model():
    model = Sequential()
    model.add(Conv2D(32, (5,5), padding="same", activation='relu', input_shape=(width, height, channels) ))
    model.add(Conv2D(32, (5,5), padding="same", activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.4))
    model.add(Conv2D(64, (3,3), padding="same", activation='relu'))
    model.add(Conv2D(64, (3,3), padding="same", activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.5))
    model.add(Flatten())
    model.add(Dense(384, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))

    opt = "adam" #Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    model.compile(loss='categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])
    return model

# %%
def plot_metrics(h, title=""):
    """ Plot training metrics - loss and accuracy, for each epoch,
        given a training history object
    """
    fig, axes = plt.subplots(1,2, figsize=(10,5))

    axes[0].plot(h.history['loss'], color="lightblue", label="Training", lw=2.0)
    axes[0].plot(h.history['val_loss'], color="steelblue", label="Validation", lw=2.0)

    axes[0].set_title("{} (Loss)".format(title))
    axes[0].set_xlabel("Epoch")
    axes[0].set_xticks(np.arange(len(h.history["loss"]), 2))
    axes[0].set_ylabel("Loss")

    axes[1].plot(h.history['accuracy'], color="lightblue", label="Training", lw=2.0)
    axes[1].plot(h.history['val_accuracy'], color="steelblue", label="Validation", lw=2.0)

    axes[1].set_title("{} (Accuracy)".format(title))
    axes[1].set_xlabel("Epoch")
    axes[1].set_xticks(np.arange(len(h.history["accuracy"]), 2))
    axes[1].set_ylabel("Accuracy")


    for axis in axes:
      axis.ticklabel_format(useOffset=False)
      axis.spines["top"].set_visible(False)
      axis.spines["right"].set_visible(False)
      axis.legend(loc='best', shadow=False)
    fig.tight_layout()

# %%
def plot_losses(batch_hist, title=""):
    fig, ax1 = plt.subplots()

    ax1.semilogx(batch_hist.losses)
    ax1.set_title("{} (Batch Loss)".format(title))

    ax1.spines["top"].set_visible(False)
    ax1.spines["right"].set_visible(False)

    plt.show()

# %% [markdown]
# Create your first model and visualize it:

# %%
model0 = create_model()

model0_batch_hist = LossHistory()

model0_metrics = model0.fit(X_train, y_train, batch_size = batch_size, epochs = epochs,
          validation_data = (X_cv, y_cv), verbose = verbose, shuffle=True, callbacks=[model0_batch_hist])

#model0.save_weights("model0.h5")
# Out:
# Epoch 1/30
# 300/300 - 166s - loss: 0.3610 - accuracy: 0.8815 - val_loss: 0.0733 - val_accuracy: 0.9769 - 166s/epoch - 553ms/step
# Epoch 2/30
# 300/300 - 163s - loss: 0.1068 - accuracy: 0.9681 - val_loss: 0.0530 - val_accuracy: 0.9844 - 163s/epoch - 542ms/step
# Epoch 3/30
# 300/300 - 162s - loss: 0.0792 - accuracy: 0.9757 - val_loss: 0.0427 - val_accuracy: 0.9874 - 162s/epoch - 540ms/step
# Epoch 4/30
# 300/300 - 162s - loss: 0.0624 - accuracy: 0.9802 - val_loss: 0.0393 - val_accuracy: 0.9887 - 162s/epoch - 541ms/step
# Epoch 5/30
# 300/300 - 162s - loss: 0.0555 - accuracy: 0.9827 - val_loss: 0.0392 - val_accuracy: 0.9887 - 162s/epoch - 540ms/step
# Epoch 6/30
# 300/300 - 152s - loss: 0.0506 - accuracy: 0.9843 - val_loss: 0.0344 - val_accuracy: 0.9896 - 152s/epoch - 507ms/step
# Epoch 7/30
# 300/300 - 162s - loss: 0.0440 - accuracy: 0.9865 - val_loss: 0.0364 - val_accuracy: 0.9896 - 162s/epoch - 541ms/step
# Epoch 8/30
# 300/300 - 163s - loss: 0.0423 - accuracy: 0.9869 - val_loss: 0.0376 - val_accuracy: 0.9888 - 163s/epoch - 542ms/step
# Epoch 9/30
# 300/300 - 165s - loss: 0.0411 - accuracy: 0.9874 - val_loss: 0.0317 - val_accuracy: 0.9907 - 165s/epoch - 549ms/step
# Epoch 10/30
# 300/300 - 163s - loss: 0.0380 - accuracy: 0.9882 - val_loss: 0.0331 - val_accuracy: 0.9911 - 163s/epoch - 545ms/step
# Epoch 11/30
# 300/300 - 163s - loss: 0.0352 - accuracy: 0.9884 - val_loss: 0.0358 - val_accuracy: 0.9904 - 163s/epoch - 544ms/step
# Epoch 12/30
# 300/300 - 166s - loss: 0.0315 - accuracy: 0.9904 - val_loss: 0.0323 - val_accuracy: 0.9910 - 166s/epoch - 553ms/step
# Epoch 13/30
# 300/300 - 165s - loss: 0.0335 - accuracy: 0.9892 - val_loss: 0.0334 - val_accuracy: 0.9892 - 165s/epoch - 549ms/step
# Epoch 14/30
# 300/300 - 164s - loss: 0.0290 - accuracy: 0.9910 - val_loss: 0.0379 - val_accuracy: 0.9899 - 164s/epoch - 547ms/step
# Epoch 15/30
# 300/300 - 166s - loss: 0.0264 - accuracy: 0.9915 - val_loss: 0.0334 - val_accuracy: 0.9907 - 166s/epoch - 553ms/step
# Epoch 16/30
# 300/300 - 167s - loss: 0.0273 - accuracy: 0.9911 - val_loss: 0.0347 - val_accuracy: 0.9910 - 167s/epoch - 556ms/step
# Epoch 17/30
# 300/300 - 164s - loss: 0.0260 - accuracy: 0.9913 - val_loss: 0.0363 - val_accuracy: 0.9899 - 164s/epoch - 546ms/step
# Epoch 18/30
# 300/300 - 162s - loss: 0.0277 - accuracy: 0.9911 - val_loss: 0.0275 - val_accuracy: 0.9927 - 162s/epoch - 540ms/step
# Epoch 19/30
# 300/300 - 154s - loss: 0.0225 - accuracy: 0.9932 - val_loss: 0.0262 - val_accuracy: 0.9929 - 154s/epoch - 512ms/step
# Epoch 20/30
# 300/300 - 156s - loss: 0.0216 - accuracy: 0.9937 - val_loss: 0.0291 - val_accuracy: 0.9915 - 156s/epoch - 520ms/step
# Epoch 21/30
# 300/300 - 172s - loss: 0.0243 - accuracy: 0.9926 - val_loss: 0.0319 - val_accuracy: 0.9893 - 172s/epoch - 573ms/step
# Epoch 22/30
# 300/300 - 163s - loss: 0.0192 - accuracy: 0.9940 - val_loss: 0.0351 - val_accuracy: 0.9910 - 163s/epoch - 544ms/step
# Epoch 23/30
# 300/300 - 162s - loss: 0.0207 - accuracy: 0.9936 - val_loss: 0.0275 - val_accuracy: 0.9924 - 162s/epoch - 541ms/step
# Epoch 24/30
# 300/300 - 162s - loss: 0.0232 - accuracy: 0.9922 - val_loss: 0.0297 - val_accuracy: 0.9918 - 162s/epoch - 540ms/step
# Epoch 25/30
# 300/300 - 162s - loss: 0.0198 - accuracy: 0.9935 - val_loss: 0.0306 - val_accuracy: 0.9924 - 162s/epoch - 540ms/step
# Epoch 26/30
# 300/300 - 162s - loss: 0.0178 - accuracy: 0.9944 - val_loss: 0.0305 - val_accuracy: 0.9918 - 162s/epoch - 541ms/step
# Epoch 27/30
# 300/300 - 162s - loss: 0.0202 - accuracy: 0.9930 - val_loss: 0.0322 - val_accuracy: 0.9919 - 162s/epoch - 540ms/step
# Epoch 28/30
# 300/300 - 162s - loss: 0.0182 - accuracy: 0.9944 - val_loss: 0.0401 - val_accuracy: 0.9888 - 162s/epoch - 539ms/step
# Epoch 29/30
# 300/300 - 162s - loss: 0.0203 - accuracy: 0.9938 - val_loss: 0.0270 - val_accuracy: 0.9938 - 162s/epoch - 539ms/step
# Epoch 30/30
# 300/300 - 162s - loss: 0.0174 - accuracy: 0.9943 - val_loss: 0.0356 - val_accuracy: 0.9920 - 162s/epoch - 539ms/step

# %% [markdown]
# ### Learning Rate Annealing

# %% [markdown]
# Learning rate is the step size in gradient descent. If the step size is too large, the system may oscillate chaotically. On the other hand, if the step size is too small, it may take too long or may settle on a local minimum.
#
# You will watch validation accuracy in each epoch and reduce the learning rate to a third if it plateaus in two consecutive epochs. Keras provides an aptly named ReduceLROnPlateau callback to adapt the learning rate based on results from each epoch. Ref: ReduceLROnPlateau for more options.
#
# The verbose mode allows you to see when the learning rate reduction actually kicks in.

# %%
learning_rate_controller = ReduceLROnPlateau(monitor='val_loss', patience=2, verbose=verbose, factor=0.3, min_lr=0.00001, epsilon=0.001)
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %% [markdown]
# [link text](https://)Create a new instance of the same model, but this time insert a callback to the learning rate control function defined above. Then fit the model to your training dataset and collect metrics.

# %%
model1 = create_model()
model1_batch_hist = LossHistory()
model1_metrics = model1.fit(X_train, y_train, batch_size = batch_size, epochs = epochs,
          validation_data = (X_cv, y_cv), verbose = verbose, shuffle=True, callbacks=[learning_rate_controller,model1_batch_hist])
#model1.save_weights("model1.h5")
# Out:
# Epoch 1/30
# 300/300 - 155s - loss: 0.3708 - accuracy: 0.8775 - val_loss: 0.0813 - val_accuracy: 0.9752 - lr: 0.0010 - 155s/epoch - 518ms/step
# Epoch 2/30
# 300/300 - 162s - loss: 0.1087 - accuracy: 0.9683 - val_loss: 0.0619 - val_accuracy: 0.9818 - lr: 0.0010 - 162s/epoch - 541ms/step
# Epoch 3/30
# 300/300 - 154s - loss: 0.0777 - accuracy: 0.9761 - val_loss: 0.0491 - val_accuracy: 0.9865 - lr: 0.0010 - 154s/epoch - 512ms/step
# Epoch 4/30
# 300/300 - 162s - loss: 0.0710 - accuracy: 0.9786 - val_loss: 0.0426 - val_accuracy: 0.9869 - lr: 0.0010 - 162s/epoch - 540ms/step
# Epoch 5/30
# 300/300 - 152s - loss: 0.0572 - accuracy: 0.9824 - val_loss: 0.0443 - val_accuracy: 0.9862 - lr: 0.0010 - 152s/epoch - 508ms/step
# Epoch 6/30
# 300/300 - 162s - loss: 0.0512 - accuracy: 0.9833 - val_loss: 0.0374 - val_accuracy: 0.9887 - lr: 0.0010 - 162s/epoch - 539ms/step
# Epoch 7/30
# 300/300 - 162s - loss: 0.0477 - accuracy: 0.9849 - val_loss: 0.0335 - val_accuracy: 0.9908 - lr: 0.0010 - 162s/epoch - 539ms/step
# Epoch 8/30
# 300/300 - 152s - loss: 0.0432 - accuracy: 0.9862 - val_loss: 0.0382 - val_accuracy: 0.9889 - lr: 0.0010 - 152s/epoch - 508ms/step
# Epoch 9/30
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 300/300 - 162s - loss: 0.0406 - accuracy: 0.9867 - val_loss: 0.0326 - val_accuracy: 0.9899 - lr: 0.0010 - 162s/epoch - 540ms/step
# Epoch 10/30
# 300/300 - 162s - loss: 0.0278 - accuracy: 0.9910 - val_loss: 0.0286 - val_accuracy: 0.9923 - lr: 3.0000e-04 - 162s/epoch - 539ms/step
# Epoch 11/30
# 300/300 - 162s - loss: 0.0220 - accuracy: 0.9931 - val_loss: 0.0289 - val_accuracy: 0.9910 - lr: 3.0000e-04 - 162s/epoch - 539ms/step
# Epoch 12/30
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 300/300 - 162s - loss: 0.0206 - accuracy: 0.9940 - val_loss: 0.0310 - val_accuracy: 0.9921 - lr: 3.0000e-04 - 162s/epoch - 539ms/step
# Epoch 13/30
# 300/300 - 162s - loss: 0.0184 - accuracy: 0.9942 - val_loss: 0.0296 - val_accuracy: 0.9919 - lr: 9.0000e-05 - 162s/epoch - 539ms/step
# Epoch 14/30
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 300/300 - 162s - loss: 0.0153 - accuracy: 0.9950 - val_loss: 0.0301 - val_accuracy: 0.9915 - lr: 9.0000e-05 - 162s/epoch - 539ms/step
# Epoch 15/30
# 300/300 - 162s - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.0299 - val_accuracy: 0.9915 - lr: 2.7000e-05 - 162s/epoch - 539ms/step
# Epoch 16/30
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1e-05.
# 300/300 - 162s - loss: 0.0159 - accuracy: 0.9952 - val_loss: 0.0297 - val_accuracy: 0.9921 - lr: 2.7000e-05 - 162s/epoch - 540ms/step
# Epoch 17/30
# 300/300 - 162s - loss: 0.0152 - accuracy: 0.9948 - val_loss: 0.0292 - val_accuracy: 0.9921 - lr: 1.0000e-05 - 162s/epoch - 538ms/step
# Epoch 18/30
# 300/300 - 162s - loss: 0.0161 - accuracy: 0.9949 - val_loss: 0.0291 - val_accuracy: 0.9919 - lr: 1.0000e-05 - 162s/epoch - 539ms/step
# Epoch 19/30
# 300/300 - 162s - loss: 0.0146 - accuracy: 0.9954 - val_loss: 0.0292 - val_accuracy: 0.9920 - lr: 1.0000e-05 - 162s/epoch - 539ms/step
# Epoch 20/30
# 300/300 - 162s - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.0293 - val_accuracy: 0.9919 - lr: 1.0000e-05 - 162s/epoch - 540ms/step
# Epoch 21/30
# 300/300 - 162s - loss: 0.0148 - accuracy: 0.9948 - val_loss: 0.0291 - val_accuracy: 0.9918 - lr: 1.0000e-05 - 162s/epoch - 540ms/step
# Epoch 22/30
# 300/300 - 162s - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.0292 - val_accuracy: 0.9920 - lr: 1.0000e-05 - 162s/epoch - 539ms/step
# Epoch 23/30
# 300/300 - 162s - loss: 0.0139 - accuracy: 0.9957 - val_loss: 0.0292 - val_accuracy: 0.9923 - lr: 1.0000e-05 - 162s/epoch - 540ms/step
# Epoch 24/30
# 300/300 - 162s - loss: 0.0136 - accuracy: 0.9954 - val_loss: 0.0292 - val_accuracy: 0.9920 - lr: 1.0000e-05 - 162s/epoch - 541ms/step
# Epoch 25/30
# 300/300 - 162s - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.0293 - val_accuracy: 0.9920 - lr: 1.0000e-05 - 162s/epoch - 539ms/step
# Epoch 26/30
# 300/300 - 162s - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.0294 - val_accuracy: 0.9920 - lr: 1.0000e-05 - 162s/epoch - 540ms/step
# Epoch 27/30
# 300/300 - 163s - loss: 0.0137 - accuracy: 0.9959 - val_loss: 0.0293 - val_accuracy: 0.9920 - lr: 1.0000e-05 - 163s/epoch - 542ms/step
# Epoch 28/30
# 300/300 - 163s - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.0295 - val_accuracy: 0.9920 - lr: 1.0000e-05 - 163s/epoch - 543ms/step
# Epoch 29/30
# 300/300 - 163s - loss: 0.0131 - accuracy: 0.9956 - val_loss: 0.0293 - val_accuracy: 0.9924 - lr: 1.0000e-05 - 163s/epoch - 544ms/step
# Epoch 30/30
# 300/300 - 163s - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.0293 - val_accuracy: 0.9921 - lr: 1.0000e-05 - 163s/epoch - 542ms/step

# %% [markdown]
# # Data Augmentation
# To reduce overfitting and to improve classification accuracy, you can augment the training samples with random transformations of images in the training set. In Keras, this is done using keras.preprocessing.image.ImageDataGenerator class. You can apply random transformations such as zooming, rotation, and shifting the image up or down. You should limit the rotation to a few degrees, and disable horizontal and vertical flipping, as this dataset of digits is prone to produce ambiguous results with these operations.
#
# See ImageDataGenerator for lots of other options that are useful for other types of images.

# %%
idg = ImageDataGenerator(
        rotation_range=10,
        zoom_range = 0.05,
        width_shift_range=0.05,
        height_shift_range=0.05,
        horizontal_flip=False,
        vertical_flip=False, data_format="channels_last")

# %% [markdown]
# Example images are generated:

# %%
image_data = idg.flow(X_train,y_train, batch_size=25).next()
print("Sample images from ImageDataGenerator:")
display_images(image_data[0], image_data[1])
# Out:
# Sample images from ImageDataGenerator:

# %% [markdown]
# # New SectionModel with data augmentation
# Create yet another instance of the model you defined earlier with the learning rate annealer. This time instead of fitting it to the training dataset, you will instead fit it to the images generated by the ImageDataGenerator. Then collect loss and accuracy metrics for comparison.

# %%
model2 = create_model()
model2_batch_hist = LossHistory()
model2_metrics = model2.fit_generator(idg.flow(X_train,y_train, batch_size=batch_size),
                    epochs = epochs,
                    steps_per_epoch=X_train.shape[0]//batch_size,
                    validation_data=(X_cv,y_cv),
                    callbacks=[learning_rate_controller,model2_batch_hist],
                    verbose = verbose)
#model2.save_weights("model2.h5")
# Out:
# Epoch 1/30
# <ipython-input-18-3b001f4965ef>:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model2_metrics = model2.fit_generator(idg.flow(X_train,y_train, batch_size=batch_size),
# 300/300 - 170s - loss: 0.4531 - accuracy: 0.8473 - val_loss: 0.0794 - val_accuracy: 0.9738 - lr: 0.0010 - 170s/epoch - 566ms/step
# Epoch 2/30
# 300/300 - 163s - loss: 0.1488 - accuracy: 0.9542 - val_loss: 0.0531 - val_accuracy: 0.9836 - lr: 0.0010 - 163s/epoch - 543ms/step
# Epoch 3/30
# 300/300 - 162s - loss: 0.1116 - accuracy: 0.9666 - val_loss: 0.0428 - val_accuracy: 0.9869 - lr: 0.0010 - 162s/epoch - 540ms/step
# Epoch 4/30
# 300/300 - 170s - loss: 0.0982 - accuracy: 0.9701 - val_loss: 0.0485 - val_accuracy: 0.9850 - lr: 0.0010 - 170s/epoch - 566ms/step
# Epoch 5/30
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 300/300 - 169s - loss: 0.0819 - accuracy: 0.9742 - val_loss: 0.0563 - val_accuracy: 0.9824 - lr: 0.0010 - 169s/epoch - 564ms/step
# Epoch 6/30
# 300/300 - 171s - loss: 0.0596 - accuracy: 0.9825 - val_loss: 0.0306 - val_accuracy: 0.9912 - lr: 3.0000e-04 - 171s/epoch - 569ms/step
# Epoch 7/30
# 300/300 - 171s - loss: 0.0526 - accuracy: 0.9835 - val_loss: 0.0287 - val_accuracy: 0.9915 - lr: 3.0000e-04 - 171s/epoch - 569ms/step
# Epoch 8/30
# 300/300 - 171s - loss: 0.0509 - accuracy: 0.9841 - val_loss: 0.0301 - val_accuracy: 0.9907 - lr: 3.0000e-04 - 171s/epoch - 570ms/step
# Epoch 9/30
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 300/300 - 169s - loss: 0.0490 - accuracy: 0.9847 - val_loss: 0.0284 - val_accuracy: 0.9923 - lr: 3.0000e-04 - 169s/epoch - 564ms/step
# Epoch 10/30
# 300/300 - 172s - loss: 0.0461 - accuracy: 0.9859 - val_loss: 0.0266 - val_accuracy: 0.9929 - lr: 9.0000e-05 - 172s/epoch - 574ms/step
# Epoch 11/30
# 300/300 - 170s - loss: 0.0417 - accuracy: 0.9871 - val_loss: 0.0252 - val_accuracy: 0.9927 - lr: 9.0000e-05 - 170s/epoch - 566ms/step
# Epoch 12/30
# 300/300 - 170s - loss: 0.0384 - accuracy: 0.9881 - val_loss: 0.0268 - val_accuracy: 0.9930 - lr: 9.0000e-05 - 170s/epoch - 565ms/step
# Epoch 13/30
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 300/300 - 160s - loss: 0.0400 - accuracy: 0.9872 - val_loss: 0.0259 - val_accuracy: 0.9927 - lr: 9.0000e-05 - 160s/epoch - 532ms/step
# Epoch 14/30
# 300/300 - 161s - loss: 0.0366 - accuracy: 0.9884 - val_loss: 0.0256 - val_accuracy: 0.9931 - lr: 2.7000e-05 - 161s/epoch - 535ms/step
# Epoch 15/30
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1e-05.
# 300/300 - 169s - loss: 0.0367 - accuracy: 0.9893 - val_loss: 0.0250 - val_accuracy: 0.9931 - lr: 2.7000e-05 - 169s/epoch - 562ms/step
# Epoch 16/30
# 300/300 - 160s - loss: 0.0372 - accuracy: 0.9881 - val_loss: 0.0247 - val_accuracy: 0.9932 - lr: 1.0000e-05 - 160s/epoch - 533ms/step
# Epoch 17/30
# 300/300 - 160s - loss: 0.0372 - accuracy: 0.9886 - val_loss: 0.0249 - val_accuracy: 0.9931 - lr: 1.0000e-05 - 160s/epoch - 532ms/step
# Epoch 18/30
# 300/300 - 169s - loss: 0.0382 - accuracy: 0.9886 - val_loss: 0.0247 - val_accuracy: 0.9932 - lr: 1.0000e-05 - 169s/epoch - 563ms/step
# Epoch 19/30
# 300/300 - 169s - loss: 0.0356 - accuracy: 0.9886 - val_loss: 0.0247 - val_accuracy: 0.9932 - lr: 1.0000e-05 - 169s/epoch - 564ms/step
# Epoch 20/30
# 300/300 - 168s - loss: 0.0353 - accuracy: 0.9896 - val_loss: 0.0247 - val_accuracy: 0.9931 - lr: 1.0000e-05 - 168s/epoch - 560ms/step
# Epoch 21/30
# 300/300 - 168s - loss: 0.0380 - accuracy: 0.9880 - val_loss: 0.0249 - val_accuracy: 0.9930 - lr: 1.0000e-05 - 168s/epoch - 560ms/step
# Epoch 22/30
# 300/300 - 168s - loss: 0.0339 - accuracy: 0.9889 - val_loss: 0.0247 - val_accuracy: 0.9932 - lr: 1.0000e-05 - 168s/epoch - 561ms/step
# Epoch 23/30
# 300/300 - 168s - loss: 0.0356 - accuracy: 0.9889 - val_loss: 0.0245 - val_accuracy: 0.9931 - lr: 1.0000e-05 - 168s/epoch - 559ms/step
# Epoch 24/30
# 300/300 - 160s - loss: 0.0368 - accuracy: 0.9882 - val_loss: 0.0244 - val_accuracy: 0.9932 - lr: 1.0000e-05 - 160s/epoch - 533ms/step
# Epoch 25/30
# 300/300 - 170s - loss: 0.0339 - accuracy: 0.9897 - val_loss: 0.0245 - val_accuracy: 0.9933 - lr: 1.0000e-05 - 170s/epoch - 565ms/step
# Epoch 26/30
# 300/300 - 170s - loss: 0.0338 - accuracy: 0.9890 - val_loss: 0.0245 - val_accuracy: 0.9932 - lr: 1.0000e-05 - 170s/epoch - 566ms/step
# Epoch 27/30
# 300/300 - 170s - loss: 0.0356 - accuracy: 0.9893 - val_loss: 0.0247 - val_accuracy: 0.9931 - lr: 1.0000e-05 - 170s/epoch - 566ms/step
# Epoch 28/30
# 300/300 - 168s - loss: 0.0358 - accuracy: 0.9883 - val_loss: 0.0246 - val_accuracy: 0.9931 - lr: 1.0000e-05 - 168s/epoch - 560ms/step
# Epoch 29/30
# 300/300 - 168s - loss: 0.0336 - accuracy: 0.9899 - val_loss: 0.0245 - val_accuracy: 0.9933 - lr: 1.0000e-05 - 168s/epoch - 559ms/step
# Epoch 30/30
# 300/300 - 168s - loss: 0.0343 - accuracy: 0.9887 - val_loss: 0.0244 - val_accuracy: 0.9932 - lr: 1.0000e-05 - 168s/epoch - 560ms/step

# %% [markdown]
# # Comparing the loss functions
# A plot of the loss function over all batches shows the effects of learning rate annealing and data augmentation. The learning rate annealer appears to reduce noise.

# %%
plot_losses(model0_batch_hist, "CNN")
plot_losses(model1_batch_hist, "CNN with Learning Rate Annealer")
plot_losses(model2_batch_hist, "CNN with Augmented Data")

# %% [markdown]
# # Results
# Keras provides a History callback that returns loss and accuracy metrics for training and validation sets for each epoch. Plots of the loss and accuracy metrics on training and validation data from the three models, help you to see the effects of learning rate annealing and data augmentation.
#
# The learning rate annealer smoothed the loss and accuracy metrics.
# Data augmentation reduced overfitting compared to the previous models.

# %%
plot_metrics(model0_metrics,"Convolutional Neural Network")
plot_metrics(model1_metrics,"CNN with Learning Rate Annealer\n")
plot_metrics(model2_metrics,"CNN with Annealer and Data Augmentation\n")

# %% [markdown]
# # Classification Accuracy
# Finally, a summary of how the three models performed in terms of training, validation and test accuracy:

# %%
models = [model0, model1, model2]
metrics = [model0_metrics, model1_metrics, model2_metrics]
names = ["Convolutional Neural Network", "CNN + Learning Rate Annealing", "CNN + LR + Data Augmentation"
         ]
data = []
for i, m in enumerate(zip(names, metrics, models)):
    data.append([m[0], "{:0.2f}".format(m[1].history["accuracy"][-1]*100), "{:0.2f}".format(m[1].history["val_accuracy"][-1]*100), "{:0.2f}".format(m[2].evaluate(X_test, y_test, verbose=0)[1]*100)])

results = pd.DataFrame(data, columns=("Model","Training Accuracy","Validation Accuracy", "Test Accuracy"))
from IPython.display import display, HTML
display(HTML(results.to_html(index=False)))
plt.bar(np.arange(len(results["Model"].values)),results["Training Accuracy"].values.astype("float64"), 0.2, color="lightblue")
plt.bar(np.arange(len(results["Model"].values))+0.2,results["Validation Accuracy"].values.astype("float64"), 0.2, color="steelblue")
plt.bar(np.arange(len(results["Model"].values))+0.4,results["Test Accuracy"].values.astype("float64"), 0.2, color="navy")
plt.ylim(97, 100)
plt.xticks(np.arange(len(results["Model"].values))+0.2, ["CNN","CNN+LR", "CNN+LR+Aug"])
plt.legend(["Training","Validation", "Test"],loc=(1,0.5))
g = plt.gca()
g.spines["top"].set_visible(False)
g.spines["right"].set_visible(False)
plt.title("Accuracy")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Model</th>
#       <th>Training Accuracy</th>
#       <th>Validation Accuracy</th>
#       <th>Test Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Convolutional Neural Network</td>
#       <td>99.43</td>
#       <td>99.20</td>
#       <td>99.33</td>
#     </tr>
#     <tr>
#       <td>CNN + Learning Rate Annealing</td>
#       <td>99.57</td>
#       <td>99.21</td>
#       <td>99.31</td>
#     </tr>
#     <tr>
#       <td>CNN + LR + Data Augmentation</td>
#       <td>98.87</td>
#       <td>99.32</td>
#       <td>99.27</td>
#     </tr>
#   </tbody>
# </table>
# Text(0.5, 1.0, 'Accuracy')
